# %% [markdown]
# # Inventory and reorder review
#
# Which coverage deficits require an inbound-stock check?
#
# All data is synthetic. Run the pipeline first. These notebooks consume the same executed reports and canonical definitions as the application. Monetary values are INR.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd() if (Path.cwd() / 'app.py').exists() else Path.cwd().parent
if str(ROOT) not in sys.path: sys.path.insert(0, str(ROOT))
import pandas as pd
from src.utils import format_inr
from database.database import read, connect

def show(frame):
    view = frame.copy()
    for column in view:
        if column.endswith('_inr'):
            view[column] = view[column].map(lambda value: format_inr(value, 2))
    print(view.to_string(index=False))

# %%
i = pd.read_csv(ROOT / 'reports/inventory_metrics.csv')
show(i[['store_id','sku','health','closing_stock','days_of_inventory','reorder_quantity','inventory_value_inr']].sort_values('reorder_quantity',ascending=False).head(15))
assert (i.reorder_quantity >= 0).all()
# Out:
#  store_id     sku         health  closing_stock  days_of_inventory  reorder_quantity inventory_value_inr
#         2 SC-0000 Critical Stock              0           0.000000              1258               ₹0.00
#         4 SC-0002      Low Stock             90           1.081545               849          ₹26,091.00
#         0 SC-0001      Low Stock            208           1.995204               848          ₹52,191.36
#         1 SC-0001      Low Stock            240           2.234043               833          ₹60,220.80
#         3 SC-0001      Low Stock            234           2.218761               829          ₹58,715.28
#         4 SC-0003      Low Stock             16           0.240343               826           ₹3,693.60
#         2 SC-0001      Low Stock            164           1.580179               820          ₹41,150.88
#         3 SC-0003      Low Stock             81           1.249587               808          ₹18,698.85
#         6 SC-0002      Low Stock            153           1.884734               791          ₹44,354.70
#         6 SC-0003      Low Stock             42           0.650083               783           ₹9,695.70
#         7 SC-0003      Low Stock             91           1.375810               776          ₹21,007.35
#         6 SC-0001      Low Stock            240           2.268737               770          ₹60,220.80
#         5 SC-0003      Low Stock             85           1.284404               764          ₹19,622.25
#         0 SC-0002      Low Stock            111           1.356021               758          ₹32,178.90
#         4 SC-0001      Low Stock            217           2.106796               757          ₹54,449.64
