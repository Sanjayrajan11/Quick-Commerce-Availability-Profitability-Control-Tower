# %% [markdown]
# # Demand patterns
#
# How does requested demand vary by hour and customer segment?
#
# All data is synthetic. Run the pipeline first. These notebooks consume the same executed reports and canonical definitions as the application. Monetary values are INR.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd() if (Path.cwd() / 'app.py').exists() else Path.cwd().parent
if str(ROOT) not in sys.path: sys.path.insert(0, str(ROOT))
import pandas as pd
from src.utils import format_inr
from database.database import read, connect

def show(frame):
    view = frame.copy()
    for column in view:
        if column.endswith('_inr'):
            view[column] = view[column].map(lambda value: format_inr(value, 2))
    print(view.to_string(index=False))

# %%
hour = pd.read_csv(ROOT / 'reports/demand_hour.csv')
show(hour[['hour','orders','quantity_ordered','net_sales_inr']])
show(pd.read_csv(ROOT / 'reports/demand_segment.csv'))
# Out:
#  hour  orders  quantity_ordered   net_sales_inr
#     7    7031           21107.0   ₹53,63,552.56
#     8   10461           31322.0   ₹79,42,672.58
#     9   17374           51736.0 ₹1,29,81,509.05
#    10   14104           42213.0 ₹1,05,83,778.83
#    11   10268           30679.0   ₹77,71,164.47
#    12   17364           51905.0 ₹1,30,58,370.77
#    13   24616           74021.0 ₹1,86,95,779.45
#    14   17279           51654.0 ₹1,30,73,793.46
#    15   10421           31159.0   ₹78,74,972.13
#    16   10489           31619.0   ₹79,43,356.22
#    17   17639           52742.0 ₹1,33,41,945.76
#    18   27772           83101.0 ₹2,09,22,907.05
#    19   34957          105048.0 ₹2,63,16,949.21
#    20   34649          104362.0 ₹2,61,48,269.56
#    21   24622           73903.0 ₹1,84,20,397.28
#    22   13895           41522.0 ₹1,02,94,431.66
#    23    7059           21259.0   ₹53,17,496.41
#      segment gross_sales_inr  discount_inr   net_sales_inr        cogs_inr gross_profit_inr variable_cost_inr contribution_profit_inr  quantity_ordered  quantity_fulfilled  quantity_unfulfilled  quantity_substituted estimated_lost_revenue_inr estimated_lost_margin_inr  orders  period_days delivery_cost_inr  fill_rate  substitution_rate  cancellation_rate  order_fulfillment_rate  item_fulfillment_rate  gross_margin  contribution_margin aov_inr profit_per_order_inr profit_per_item_inr recovery_opportunity_inr
#    Household ₹8,07,58,856.26 ₹51,36,188.91 ₹7,56,22,667.35 ₹5,23,19,467.98  ₹2,33,03,199.37     ₹48,26,540.07         ₹1,84,76,659.30          301595.0            299559.0                2036.0                1276.0               ₹5,64,221.38              ₹1,87,869.50  100581          120     ₹30,19,338.79   0.993249           0.004231           0.001422                0.998578               0.993384      0.308151             0.244327 ₹751.86              ₹183.70              ₹61.68             ₹3,66,743.90
# Professional ₹8,01,36,910.93 ₹50,31,414.95 ₹7,51,05,495.98 ₹5,18,62,702.09  ₹2,32,42,793.89     ₹47,77,983.01         ₹1,84,64,810.88          298138.0            296186.0                1952.0                1188.0               ₹5,00,008.41              ₹1,65,781.99   99469          120     ₹29,85,583.04   0.993453           0.003985           0.001468                0.998532               0.993436      0.309469             0.245852 ₹755.06              ₹185.63              ₹62.34             ₹3,25,005.47
#      Student ₹8,04,09,394.42 ₹50,86,959.30 ₹7,53,22,435.12 ₹5,20,64,629.91  ₹2,32,57,805.21     ₹47,98,076.25         ₹1,84,59,728.96          299617.0            297663.0                1954.0                1287.0               ₹5,39,484.60              ₹1,82,647.30   99949          120     ₹30,00,565.74   0.993478           0.004295           0.001501                0.998499               0.993437      0.308777             0.245076 ₹753.61              ₹184.69              ₹62.02             ₹3,50,664.99
#      Unknown         ₹748.00         ₹0.00         ₹748.00         ₹486.20          ₹261.80            ₹41.10                 ₹220.70               2.0                 2.0                   0.0                   0.0                      ₹0.00                     ₹0.00       1            1            ₹16.84   1.000000           0.000000           0.000000                1.000000               1.000000      0.350000             0.295053 ₹748.00              ₹220.70             ₹110.35                    ₹0.00
