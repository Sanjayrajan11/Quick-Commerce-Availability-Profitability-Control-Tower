# %% [markdown]
# # Quality audit
#
# Which controlled defects were detected and how many records were repaired?
#
# All data is synthetic. Run the pipeline first. These notebooks consume the same executed reports and canonical definitions as the application. Monetary values are INR.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd() if (Path.cwd() / 'app.py').exists() else Path.cwd().parent
if str(ROOT) not in sys.path: sys.path.insert(0, str(ROOT))
import pandas as pd
from src.utils import format_inr
from database.database import read, connect

def show(frame):
    view = frame.copy()
    for column in view:
        if column.endswith('_inr'):
            view[column] = view[column].map(lambda value: format_inr(value, 2))
    print(view.to_string(index=False))

# %%
q = pd.read_csv(ROOT / 'reports/data_quality_report.csv')
show(q)
assert q.records_removed.sum() == 1
# Out:
#                    table  total_records  missing_values  duplicate_records  invalid_values  outliers  referential_integrity_issues  records_removed  records_corrected  records_retained  records_added
#               DIM_REGION              2               0                  0               0         0                             0                0                  0                 2              0
#                 DIM_CITY              4               0                  0               0         0                             0                0                  0                 4              0
#                DIM_STORE              8               0                  0               0         0                             0                0                  0                 8              0
#     DIM_STORE_OPERATIONS              8               0                  0               0         0                             0                0                  0                 8              0
#             DIM_CATEGORY              4               0                  0               0         0                             0                0                  0                 4              0
#             DIM_SUPPLIER              4               0                  0               0         0                             0                0                  0                 4              0
#              DIM_PRODUCT             40               0                  0               1         0                             1                0                  1                40              0
#             DIM_CUSTOMER          30000               0                  0               0         0                             0                0                  0             30000              1
#                 DIM_DATE            120               0                  0               0         0                             0                0                  0               120              0
#            DIM_PROMOTION              3               0                  0               0         0                             0                0                  0                 3              0
#     DIM_DELIVERY_PARTNER              2               0                  0               0         0                             0                0                  0                 2              0
#              FACT_ORDERS         300001               1                  1               2         0                             1                1                  4            300000              0
#         FACT_ORDER_ITEMS         702781               0                  0               0         0                             0                0                  0            702781              0
# FACT_INVENTORY_SNAPSHOTS          38400               0                  0               0         0                             0                0                  0             38400              0
#            FACT_DELIVERY         300000               0                  0               0         1                             0                0                  1            300000              0
#          FACT_PROMOTIONS         102369               0                  0               0         0                             0                0                  0            102369              0
